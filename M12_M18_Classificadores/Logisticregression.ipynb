# %%
import preprocessing as pre
import logisticregression as lr

import numpy as np
import pandas as pd

# %%
caminho = "C:\\Users\\Nitro\\Desktop\\Redes-Neurais\\titanic.csv"

# %%
def printAccuracy(confusionMatrix):
    accuracy = (confusionMatrix[0][0] + confusionMatrix[1][1]) / (confusionMatrix[0][0] + confusionMatrix[1][0] + confusionMatrix[0][1] + confusionMatrix[1][1])
    print(accuracy * 100)

# %%
confusionMatrix = lr.computeLogisticRegressionExample(caminho)
print(confusionMatrix)
printAccuracy(confusionMatrix)
# Out:
# [[80  9]
#  [10 35]]
# 85.82089552238806
